# %%
import pandas as pd

# Substitua 'arquivo.csv' pelo nome do seu arquivo
df = pd.read_csv("brasileirao_standings.csv")
display(df)
# Out:
#     Temporada  Posicao                 Time  Pontos  Saldo de Gols  Jogos  \
# 0        2021        1          Atletico-MG      84             33     38
# 1        2021        2             Flamengo      71             33     38
# 2        2021        3            Palmeiras      66             15     38
# 3        2021        4         Fortaleza EC      58             -1     38
# 4        2021        5          Corinthians      57              4     38
# 5        2021        6        RB Bragantino      56              9     38
# 6        2021        7           Fluminense      54              0     38
# 7        2021        8      America Mineiro      53              4     38
# 8        2021        9  Atletico Goianiense      53             -3     38
# 9        2021       10               Santos      50             -5     38
# 10       2021       11                Ceara      50              1     38
# 11       2021       12        Internacional      48              2     38
# ...
